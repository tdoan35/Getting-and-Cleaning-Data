# %% [markdown]
# ## Week 1 Quiz

# %% [markdown]
# <b>Problem 1 </b><br>
# The American Community Survey distributes downloadable data about United States communities. Download the 2006 microdata survey about housing for the state of Idaho using download.file() from here:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Fss06hid.csv
#
# and load the data into R. The code book, describing the variable names is here:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2FPUMSDataDict06.pdf
#
# How many properties are worth $1,000,000 or more?

# %%
fileURL <- "https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Fss06hid.csv"
download.file(fileURL, destfile="./data/2006microdatasurvey.csv", method="curl")

# %%
list.files("./data/")
# Out:
# [1] "2006microdatasurvey.csv" "data"
# [3] "Week 1 Quiz.ipynb"       "Week 1.ipynb"

# %%
dateDownloaded <- date()
dateDownloaded
# Out:
# [1] "Sat Mar 25 15:43:16 2017"

# %%
surveydata <- read.csv("./data/2006microdatasurvey.csv")
head(surveydata, n=10)
# Out:
#    RT SERIALNO DIVISION PUMA REGION ST ADJUST  WGTP NP TYPE ⋯ wgtp71 wgtp72
# 1  H   186     8        700  4      16 1015675  89  4  1    ⋯  81     27
# 2  H   306     8        700  4      16 1015675 310  1  1    ⋯ 292    401
# 3  H   395     8        100  4      16 1015675 106  2  1    ⋯ 123    119
# 4  H   506     8        700  4      16 1015675 240  4  1    ⋯  68    359
# 5  H   835     8        800  4      16 1015675 118  4  1    ⋯ 127     36
# 6  H   989     8        700  4      16 1015675 115  4  1    ⋯ 120     34
# 7  H  1861     8        700  4      16 1015675   0  1  2    ⋯   0      0
# 8  H  2120     8        200  4      16 1015675  35  1  1    ⋯  40     36
# 9  H  2278     8        400  4      16 1015675  47  2  1    ⋯  14     12
# 10 H  2428     8        500  4      16 1015675  51  2  1    ⋯  89     83
#    wgtp73 wgtp74 wgtp75 wgtp76 wgtp77 wgtp78 wgtp79 wgtp80
# 1   93    151     28     79     25    101    157    129
# ...

# %%
surveydata$VAL >= 24
# Out:
#    [1] FALSE    NA FALSE FALSE FALSE FALSE    NA    NA FALSE FALSE FALSE FALSE
#   [13] FALSE    NA    NA FALSE FALSE FALSE    NA    NA    NA FALSE    NA    NA
#   [25] FALSE FALSE    NA FALSE FALSE    NA FALSE FALSE FALSE FALSE FALSE FALSE
#   [37] FALSE    NA FALSE FALSE FALSE    NA FALSE FALSE FALSE    NA FALSE FALSE
#   [49]    NA    NA FALSE FALSE    NA FALSE FALSE FALSE    NA    NA FALSE FALSE
#   [61] FALSE    NA FALSE FALSE FALSE FALSE FALSE FALSE FALSE    NA FALSE    NA
#   [73] FALSE FALSE FALSE FALSE    NA    NA    NA FALSE FALSE FALSE FALSE    NA
#   [85]    NA    NA FALSE    NA FALSE FALSE FALSE FALSE FALSE FALSE    NA FALSE
#   [97] FALSE FALSE FALSE FALSE FALSE    NA FALSE FALSE FALSE FALSE    NA    NA
#  [109]    NA    NA FALSE FALSE    NA FALSE FALSE    NA FALSE    NA FALSE FALSE
#  [121]    NA    NA    NA FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [133]    NA FALSE FALSE FALSE    NA FALSE FALSE    NA FALSE    NA FALSE    NA
# ...

# %%
sum((surveydata$VAL >= 24), na.rm=TRUE)
# Out:
# [1] 53

# %% [markdown]
# <b>Problem 2</b><br>
# Use the data you loaded from Question 1. Consider the variable FES in the code book. Which of the "tidy data" principles does this variable violate?

# %%
head(surveydata$FES)
# Out:
# [1]  2 NA  7  1  1  2

# %% [markdown]
# Tidy data has one variable per column. FES has gender, marital status, and employment status

# %% [markdown]
# <b>Problem 3</b><br>
# Download the Excel spreadsheet on Natural Gas Aquisition Program here:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2FDATA.gov_NGAP.xlsx
#
# Read rows 18-23 and columns 7-15 into R and assign the result to a variable called:

# %% [raw]
# dat

# %% [markdown]
# What is the value of:

# %% [raw]
# sum(dat$Zip*dat$Ext,na.rm=T)

# %% [markdown]
# (original data source: http://catalog.data.gov/dataset/natural-gas-acquisition-program)

# %%
fileURL <- "https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2FDATA.gov_NGAP.xlsx"
download.file(fileURL, destfile="./data/NGasData.xlsx", method="curl")
dateDownloaded <- date()
dateDownloaded
# Out:
# [1] "Sat Mar 25 16:02:49 2017"

# %%
library(xlsx)
nGasAqData <- read.xlsx("./data/NGasData.xlsx", sheetIndex = 1, header = TRUE)
head(nGasAqData)
# Out:
# Loading required package: rJava
# Loading required package: xlsxjars
#   Table.Name..Contract NA.          NA..1               NA..2
# 1 ContractNumber       ContractorId ExpiryDate          CFileName
# 2 GS-00P-02-BSC-0201   23           2004-09-30 00:00:00 NA
# 3 GS-00P-02-BSC-0204   5            2003-10-31 00:00:00 NULL
# 4 GS-00P-02-BSC-0206   6            2004-10-31 00:00:00 NA
# 5 GS-00P-02-BSC-0207   4            2006-10-31 00:00:00 NA
# 6 GS-00P-02-BSC-0209   7            2004-10-31 00:00:00 NA
#   NA..3               NA..4 NA..5 NA..6 NA..7 NA..8 ⋯ NA..15 NA..16 NA..17
# 1 ReactivationDt      NA    NA    NA    NA    NA    ⋯ NA     NA     NA
# 2 2004-09-30 00:00:00 NA    NA    NA    NA    NA    ⋯ NA     NA     NA
# 3 NULL                NA    NA    NA    NA    NA    ⋯ NA     NA     NA
# 4 2004-11-02 00:00:00 NA    NA    NA    NA    NA    ⋯ NA     NA     NA
# 5 2004-11-01 00:00:00 NA    NA    NA    NA    NA    ⋯ NA     NA     NA
# ...

# %%
rowIndex <- 18:23
colIndex <- 7:15
dat <- read.xlsx("./data/NGasData.xlsx", sheetIndex = 1, header = TRUE, colIndex=colIndex, rowIndex=rowIndex)
head(dat)
# Out:
#   Zip   CuCurrent PaCurrent PoCurrent Contact      Ext Fax          email
# 1 74136 0         1         0         918-491-6998   0 918-491-6659 NA
# 2 30329 1         0         0         404-321-5711  NA NA           NA
# 3 74136 1         0         0         918-523-2516   0 918-523-2522 NA
# 4 80203 0         1         0         303-864-1919   0 NA           NA
# 5 80120 1         0         0         345-098-8890 456 NA           NA
#   Status
# 1 1
# 2 1
# 3 1
# 4 1
# 5 1

# %%
sum(dat$Zip*dat$Ext, na.rm=T)
# Out:
# [1] 36534720

# %% [markdown]
# <b>Problem 4</b><br>
# Read the XML data on Baltimore restaurants from here:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Frestaurants.xml
#
# How many restaurants have zipcode 21231?

# %%
library(XML)
doc <- xmlTreeParse("./Data/BaltimoreRestaurants.xml", useInternal=TRUE)
rootNode <- xmlRoot(doc)
xmlName(rootNode)
# Out:
# [1] "response"

# %%
zipcode <- xpathSApply(rootNode, "//zipcode", xmlValue)
length(zipcode[zipcode==21231])
# Out:
# [1] 127

# %% [markdown]
# <b>Problem 5</b>
# The American Community Survey distributes downloadable data about United States communities. Download the 2006 microdata survey about housing for the state of Idaho using download.file() from here:
#
# https://d396qusza40orc.cloudfront.net/getdata%2Fdata%2Fss06pid.csv
#
# using the fread() command load the data into an R object

# %% [raw]
# DT

# %% [markdown]
# The following are ways to calculate the average value of the variable

# %% [raw]
# pwgtp15

# %% [markdown]
# broken down by sex. Using the data.table package, which will deliver the fastest user time?

# %%
library(data.table)
DT <- fread(input="./data/2006microdatasurvey.csv", sep=",")
system.time(mean(DT$pwgtp15, by=DT$SEX))
# Out:
# Warning message in mean.default(DT$pwgtp15, by = DT$SEX):
# “argument is not numeric or logical: returning NA”
#    user  system elapsed
#   0.002   0.001   0.002

# %%
system.time(tapply(DT$pwgtp15,DT$SEX,mean))
# Out:
# Error in split.default(X, group): first argument must be a vector
# Traceback:
#
# 1. system.time(tapply(DT$pwgtp15, DT$SEX, mean))
# 2. tapply(DT$pwgtp15, DT$SEX, mean)
# 3. split(X, group)
# 4. split.default(X, group)
# Timing stopped at: 0.003 0 0.003

# %%
system.time(mean(DT[DT$SEX==1,]$pwgtp15); mean(DT[DT$SEX==2,]$pwgtp15))
# Out:
# Error in parse(text = x, srcfile = src): <text>:1:41: unexpected ';'
# 1: system.time(mean(DT[DT$SEX==1,]$pwgtp15);
#                                             ^
# Traceback:
